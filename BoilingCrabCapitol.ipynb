# %% [markdown]
# # Final Project: Boiling Crab Capitol
# Kathy Quinto, Luis Arteaga, Mai Chee Vang, ENGR 120
# Last Updated: 12/12/2017
#
# Purpose: Get links, Scrape reviews from individual pages into separate lists, Combined all lists into a master list, Remove stop words from master list, Compile into .txt file

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
from re import findall
import pandas as pd

# %% [markdown]
# # Boiling Crab on Capitol Expy

# %%
url1 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab'
url2 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=20'
url3 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=40'
url4 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=60'
url5 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=80'
url6 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=100'
url7 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=120'
url8 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=140'
url9 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=160'
url10 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=180'
url11 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=200'
url12 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=220'
url13 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=240'
url14 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=260'
url15 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=280'
url16 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=300'
url17 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=320'
url18 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=340'
url19 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=360'
url20 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose?osq=The+Boiling+Crab&start=380'

# %%
def scrape_comment(link):
    """Returns parsed HTML content for COMMENT"""
    
    response = urlopen(link)
    content = response.read()
    response.close()
    
    #parse HTML file
    content_soup = soup(content, 'html.parser')

    
    #parse HTML file
    review_comment = content_soup.findAll("p", {"lang" : "en"})
    review_str = str(review_comment)
    review_lower = review_str.lower()
    new_list1 = review_lower.replace('[<p', '')
    new_list2 = new_list1.replace('br', '')
    new_list3 = new_list2.replace('lang','')
    new_list4 = new_list3.replace('[', '')
    new_list5 = new_list4.replace('<', '')
    new_list6 = new_list5.replace('=', '')
    new_list7 = new_list6.replace('"en"', '')
    new_list8 = new_list7.replace('>', '')
    new_list9 = new_list8.replace('/', '')
    new_list10 = new_list9.replace('.', '')
    new_list11 = new_list10.replace('?', '')
    new_list12 = new_list11.replace('"', '')
    new_list13 = new_list12.replace(',', '')
    new_list14 = new_list13.replace('(', '')
    new_list15 = new_list14.replace(')', '')
    review_list = new_list15.split()
    return(review_list)

# %%
#url1
page1 = scrape_comment(url1)
print(page1)
# Out:
# ['been', 'there', 'once', 'very', 'spacious', 'and', 'busy', "tooit's", 'very', 'casual', 'yellow', 'light', 'comfythe', 'waiting', 'was', '15', 'mins', 'not', 'too', 'badi', 'like', 'food', 'there', 'a', 'lotp', 'p', 'what', 'happened', 'to', 'this', 'place', 'it', 'use', 'to', 'be', 'so', 'good!i', 'live', 'like', '5', 'minutes', 'away', 'from', 'this', 'bc', 'location', 'and', 'use', 'to', 'go', 'here', 'at', 'least', 'once', 'a', 'month', 'but', 'i', "haven't", 'been', 'back', 'for', 'over', '25', 'years', 'ever', 'since', 'i', 'discovered', 'a', 'new', 'crawfish', 'place', 'on', 'berryessa', 'so', 'last', 'friday', 'we', 'were', 'lazy', 'to', 'drive', 'far', 'and', 'decided', 'to', 'give', 'them', 'another', 'try', 'we', 'ordered', '2', 'lbs', 'of', 'shrimp', '+', '2', 'lbs', 'of', 'crawfish', '+', '2', 'corns', 'shabang', 'medium', 'cajun', 'fries', 'cajun', 'wings', 'and', 'a', 'side', 'of', 'extra', 'sauce', 'crawfish', 'was', 'not', 'in', 'season', 'so', 'i', "wasn't", 'expe
# ...

# %%
#url2
page2 = scrape_comment(url2)
print(page2)
# Out:
# ['roll', 'up', 'your', 'sleeves', 'put', 'on', 'a', 'bib', 'and', 'dig', 'into', 'your', 'bag', 'of', 'choice', 'seafood!', 'a', 'group', 'of', 'friends', 'were', 'in', 'town', 'visiting', 'and', 'this', 'was', 'the', 'place', 'we', 'were', 'meeting', 'up', 'to', 'have', 'dinner', 'at', 'it', 'was', 'a', 'wednesday', 'night', 'no', 'reservations', 'needed', "i'm", 'actually', 'not', 'sure', 'if', 'they', 'even', 'take', 'them', 'the', 'wait', 'about', '15', 'minutes', 'around', '7pm', 'i', 'was', 'running', 'a', 'little', 'later', 'so', 'we', 'were', 'seated', 'right', 'when', 'i', 'got', 'there', 'there', "isn't", 'much', 'to', 'the', 'menu', '--', 'pick', 'your', 'seafood', 'what', 'flavors', "you'd", 'like', 'on', 'there', 'and', 'how', 'hot', "you'd", 'like', 'it', 'they', 'also', 'have', 'sides', 'which', 'we', 'all', 'did', 'get', 'so', "don't", 'forget', 'to', 'order', 'some', 'of', 'them!', 'myself', 'and', 'my', 'other', 'good', 'friend', 'have', 'never', 'been', 'there', 's
# ...

# %%
#url3
page3 = scrape_comment(url3)
print(page3)
# Out:
# ['this', 'was', 'actually', 'not', 'a', 'bad', 'experience', 'they', 'are', 'very', 'busy', 'but', 'they', 'took', 'our', 'order', 'before', 'seating', 'so', 'that', 'was', 'nice', 'the', 'food', 'quality', 'was', 'good', 'as', 'well', 'it', 'is', 'a', 'bit', 'surprising', 'when', 'they', 'put', 'the', 'bag', 'on', 'the', 'table', 'but', 'we', 'adjusted', 'and', 'enjoyed', 'the', 'food', 'oysters', 'mussels', 'and', 'king', 'crab', 'plus', 'a', 'margarita', 'all', 'very', 'nice:p', 'p', "i've", 'been', 'wanting', 'to', 'eat', 'at', 'boiling', 'crab', 'for', 'several', 'years', 'and', 'finally', 'had', 'the', 'chance', 'to', 'come', 'here', 'recently', 'with', 'one', 'of', 'my', 'colleagueswe', 'reached', 'the', 'restaurant', '5', 'minutes', 'before', 'the', 'opening', 'time', 'and', 'there', 'was', 'already', 'a', 'few', 'people', 'waiting', 'in', 'line', 'ahead', 'of', 'usas', 'soon', 'as', 'the', 'restaurant', 'doors', 'opened', 'we', 'got', 'seated', 'comfortably', 'in', 'one', 'o
# ...

# %%
#url4
page4 = scrape_comment(url4)
print(page4)
# Out:
# ["i'm", 'allergic', 'to', 'shrimp', 'but', 'i', 'still', 'eat', 'the', 'shrimp', 'here', 'because', "it's", 'so', 'damn', 'good', 'i', 'just', 'take', 'benadryl', 'and', "it's", 'fine', "it's", 'worth', 'getting', 'the', 'hives', "that'll", 'fade', 'after', 'a', 'couple', 'hours', 'the', 'sauce', 'is', 'freaking', "amazingi'm", 'drooling', 'as', 'i', 'write', 'thisexpect', 'to', 'wait', 'around', 'an', 'hour', 'and', 'a', "halfthat's", 'normal', '-', 'no', 'matter', 'what', 'time', 'you', 'go', "it's", 'definitely', 'worth', 'it', 'and', 'you', 'could', 'shop', 'around', 'the', 'plaza', 'after', 'you', 'put', 'your', 'name', 'down', 'they', 'give', 'you', 'a', 'plastic', 'bib', 'but', 'it', 'gets', 'pretty', 'messy', 'so', 'prepare', 'to', 'stain', 'your', 'shirt', 'with', 'boiling', 'crab', 'sauce', 'best', 'seafood', 'place', 'ever', 'love', 'ittttp', 'p', 'the', 'food', 'is', 'delicious', 'here', 'no', 'matter', 'what', 'you', 'order', 'but', 'my', 'personal', 'preferences', 'are'
# ...

# %%
#url5
page5 = scrape_comment(url5)
print(page5)
# Out:
# ['just', 'like', 'most', 'good', 'restaurants', "they're", 'busy', 'and', 'you', 'have', 'to', 'wait', 'for', 'the', 'fresh', 'food', 'i', "wouldn't", 'recommend', 'it', 'as', 'a', 'first', 'date', 'place', 'cuz', 'you', 'peel', 'the', 'shrimp', 'and', 'crab', 'yourself', 'and', 'your', 'hands', 'get', 'the', 'delicious', 'sauce', 'all', 'over', 'them', 'all', 'and', 'all', 'i', 'think', 'it', 'was', 'worth', 'the', 'one', 'hour', 'wait', 'and', 'so', 'did', 'all', 'the', 'customers', 'who', 'were', 'before', 'usp', 'p', 'loved', 'the', 'shrimps', 'here', 'sweet', 'potato', 'fries', 'and', 'great', 'too', 'always', 'go', 'during', 'off', 'peak', 'hours', 'to', 'beat', 'the', 'crowdp', 'p', 'waited', 'like', 'an', 'hour', 'and', 'thirty', 'minutes', 'was', 'it', 'worth', 'it', 'yah', 'lolwe', 'ordered:-6', 'raw', 'oysters-3', 'pounds', 'of', 'shrimp', 'w', 'whole', 'shabang', 'mildonly', 'complaint', 'is', 'that', 'half', 'of', 'my', 'shrimps', 'were', 'decapitated', ':', 'this', 'pla
# ...

# %%
#url6
page6 = scrape_comment(url6)
print(page6)
# Out:
# ['when', 'i', 'first', 'came', 'here', '15', 'years', 'ago', 'i', 'would', 'have', 'given', 'this', 'place', '5', 'stars', 'over', 'time', 'i', 'feel', 'like', 'the', 'quality', 'has', 'gone', 'way', 'downhillthe', 'food', 'comes', 'out', 'warm', 'and', 'gets', 'cold', 'pretty', 'quickly', 'theres', 'not', 'a', 'lot', 'of', 'sauce', 'in', 'the', 'bag', 'and', 'the', 'seafood', 'is', 'over', 'cooked', 'the', 'mussels', 'are', 'chewy', 'the', 'shrimp', 'is', 'hard', 'to', 'peel', 'and', 'the', 'rice', 'is', 'warmwhen', 'i', 'first', 'started', 'coming', 'here', 'the', 'food', 'was', 'cooked', 'perfectly', 'and', 'everything', 'would', 'come', 'out', 'piping', 'hotsorry', 'boiling', 'crab', 'but', 'you', 'just', "don't", 'do', 'it', 'for', 'me', 'anymore', 'i', 'always', 'go', 'to', 'the', "kickin'", 'crab', 'now', 'there', 'is', 'usually', 'a', 'shorter', 'wait', 'the', 'food', 'comes', 'out', 'perfect', 'and', 'piping', 'hot', 'and', 'there', 'is', 'enough', 'sauce', 'in', 'the', 'bag
# ...

# %%
#url7
page7 = scrape_comment(url7)
print(page7)
# Out:
# ['i', 'used', 'to', 'love', 'love', 'love', 'boiling', 'crab', 'been', 'to', 'many', 'of', 'their', 'locations', 'in', 'sol', 'cal', 'and', 'nor', 'cal', 'this', 'time', 'i', 'am', 'super', 'disappointed', 'i', 'ordered', 'togo', '2', 'pound', 'southern', 'king', 'crab', 'legs', 'with', 'sausages', 'in', 'medium', 'whole', 'she', 'bang', 'the', 'leg', 'themselves', 'are', 'overcooked', 'not', 'only', 'they', 'took', 'a', 'long', 'time', 'for', 'my', 'food', 'the', "'sauce'", 'was', 'dry', 'and', 'powdery', 'no', 'liquid', 'at', 'all', 'they', 'also', 'changed', 'their', 'sausages', 'order', 'instead', 'of', 'by', 'pieces', 'they', 'charge', 'it', 'by', 'pound', 'now', 'i', 'am', 'going', 'to', 'elsewherep', 'p', 'the', 'whole', 'shabang', 'sauce', '12', 'pd', 'of', 'shrimp', 'and', '3', 'cornwith', 'a', 'side', 'of', 'cajun', 'fries', 'please!!this', 'place', 'will', 'leave', 'you', 'satisfied', 'and', 'coming', 'back', 'for', 'more!', 'the', 'wait', 'can', 'definitely', 'be', 'very'
# ...

# %%
#url8
page8 = scrape_comment(url8)
print(page8)
# Out:
# ['nothe', 'sauce', 'was', 'bitter', 'and', 'contained', 'hardly', 'any', 'liquid', 'the', 'shrimp', 'itself', 'was', 'decent', 'quality', 'but', 'overall', 'the', 'experience', 'was', 'lacklustre', 'especially', 'when', 'compared', 'with', 'claw', 'shack', 'mmmm', "shackie's", 'sauce', 'what', 'i', 'would', 'recommend', 'here', 'though', 'is', 'the', 'wings', 'they', 'were', 'crispy', 'and', 'juicy', 'really', 'delicious', 'service', 'was', 'good', 'but', 'nothing', 'special', 'felt', 'like', 'a', 'one-and-done', 'experience', 'rather', 'than', 'having', 'warmthp', 'p', 'i', 'got', 'some', 'clams', 'the', 'whole', 'shabang', 'the', 'clams', 'were', 'super', 'undercooked', 'and', 'slimy', 'it', 'was', 'literally', 'like', 'transparent-ish', 'goo', 'they', 'were', 'literally', 'falling', 'apart', 'and', 'oozyp', 'p', 'came', 'here', 'twice', 'in', 'the', 'same', 'week', 'for', 'two', 'separate', 'family', 'dinners', 'and', 'this', 'place', 'has', 'definitely', 'grown', 'on', 'me!', ':'
# ...

# %%
#url9
page9 = scrape_comment(url9)
print(page9)
# Out:
# ['there', 'are', 'other', 'places', 'and', 'then', 'there', 'is', 'the', 'boiling', 'crab', 'perfect', 'sauce', 'the', 'whole', 'shabang', 'literally', 'blows', 'your', 'mind', 'well', 'cooked', 'proteins', 'and', 'great', 'sides', 'special', 'shout', 'out', 'to', 'the', 'lemon', 'pepper', 'fries', 'yum!', 'we', 'polished', 'off:3', 'pounds', 'of', 'shrimp:', 'polished', 'off', 'between', '2', 'people', '1', 'pound', 'clams:', 'recommendedone', 'entire', 'dungeoness', 'crab:', 'finished', 'in', 'under', '7', 'min1', 'pound', 'snow', 'crab', 'legs:', 'tough', 'to', 'crack', 'but', 'worth', 'the', 'effortlemon', 'pepper', 'fries-', 'yumthere', 'was', 'some', 'chicken', 'on', 'the', 'table', 'but', 'i', "don't", 'remember', 'what', 'it', 'wasonly', 'come', 'here', 'if', 'you', 'like', 'eating', 'messy', 'at', 'times', 'and', 'be', 'careful', 'not', 'to', 'get', 'the', 'sauce', 'in', 'your', 'eyes', 'my', 'friend', 'ordered', 'the', 'triple', 'x', 'and', 'ended', 'up', 'splashing', 'it',
# ...

# %%
#url10
page10 = scrape_comment(url10)
print(page10)
# Out:
# ['love', 'this', 'place', 'but', 'they', 'are', 'getting', 'stingy', 'on', 'the', 'sauce', '!', 'all', 'of', 'it', 'was', 'garlic', 'and', 'my', 'snow', 'crab', 'looked', 'like', 'dungenous', 'crab', '!', 'you', 'guys', 'will', 'always', 'be', 'great!', 'but', "don't", 'mess', 'up', 'the', 'sauce', '!p', 'p', 'the', 'hosts', 'are', 'rude', 'customer', 'service', 'is', 'horrible', 'today', 'was', 'the', 'third', 'time', 'i', 'experienced', 'rudeness', 'so', 'i', 'can', 'surely', 'say', 'they', "weren't", 'just', 'having', 'a', 'bad', 'day', 'the', 'first', 'time', 'i', 'went', 'at', 'one', 'point', 'i', 'was', 'standing', 'there', 'waiting', 'to', 'be', 'helped', 'and', 'there', 'was', 'one', 'host', 'writing', 'on', 'his', 'pad', 'and', 'another', 'host', 'sitting', 'there', 'doing', 'nothing', 'and', 'told', 'me', 'to', 'wait', 'to', 'be', 'helped', 'by', 'the', 'other', 'the', 'customer', 'service', 'here', 'is', 'terrible', 'i', 'ended', 'up', 'leaving', 'when', 'i', 'received', '
# ...

# %%
#url11
page11 = scrape_comment(url11)
print(page11)
# Out:
# ['very', 'fast', 'and', 'professional', 'service', 'diverse', 'menu', 'clean', 'and', 'no', 'seafood', 'smelling', 'i', 'like', 'the', 'crawfish', 'with', 'cajun', 'saucep', 'p', 'love', 'the', 'boiling', 'crab', 'even', 'drove', 'an', 'extra', '45', 'minutes', 'as', 'the', 'closest', 'thing', 'to', 'this', 'in', 'the', 'peninsula', 'was', 'the', 'red', 'crawfish;', 'however', 'it', 'changed', 'hands', 'and', 'we', 'wanted', 'something', 'we', 'knew', 'would', 'hit', 'the', 'spotfirst', 'time', 'at', 'this', 'original', 'location', 'as', 'we', 'usually', 'hit', 'the', 'larger', 'location', 'on', 'curtner', 'rd', 'waited', 'about', '30', 'minutes', 'around', '6pm', 'and', 'the', 'place', 'got', 'really', 'packed', 'afterwardstoo', 'bad', 'the', 'dungeness', 'crab', 'was', 'frozen', 'at', '$16lb', 'as', 'we', 'would', 'have', 'jumped', 'all', 'over', 'it', 'if', 'it', 'was', 'fresh', 'instead', 'we', 'got', 'the', 'gumbo', 'wrice', 'nicely', 'loaded', 'with', 'andouille', 'sausage', 'o
# ...

# %%
#url12
page12 = scrape_comment(url12)
print(page12)
# Out:
# ['drove', '90', 'minutes', 'each', 'way', 'over', '100', 'miles', 'and', '$50', 'in', 'gas', 'wear&amp;tear', 'on', 'my', 'car', 'round', 'trip', 'to', 'eat', 'here', 'my', 'favorite', 'restaurant', 'fought', 'through', 'traffic', 'to', 'get', 'here', 'and', 'find', 'out', 'they', 'were', 'closed', 'on', '1223', 'their', 'website', "didn't", 'say', 'anything', 'about', 'the', 'closure', 'yelp', 'or', 'google', "didn't", 'have', 'anything', 'about', 'their', 'closure', 'all', 'signs', 'pointed', 'to', 'deliciousness', 'pretty', 'frustrated', 'if', 'you', 'were', 'having', 'some', 'kind', 'of', 'holiday', 'party', 'for', 'your', 'staff', 'great!', 'they', 'deserve', 'it!!', 'just', 'let', 'people', 'know', 'because', 'you', 'refuse', 'to', 'do', 'call', 'ahead', 'seating', 'or', 'take', 'reservations', 'i', 'have', 'to', 'plan', 'around', 'this', 'trip', 'total', 'bummer', 'when', 'it', "doesn't", 'happen', 'even', 'worse', 'when', 'i', 'drive', 'there', 'and', "you're", 'inexplicably'
# ...

# %%
#url13
page13 = scrape_comment(url13)
print(page13)
# Out:
# ['3', 'stars', 'for', 'the', 'delicious', 'food', 'and', 'an', 'additional', 'star', 'for', 'the', 'amazing', 'customer', 'service!it', 'took', 'me', 'a', 'while', 'to', 'finally', 'try', 'boiling', 'crab', 'but', 'now', "i've", 'had', 'it', 'for', '3', 'weekends', 'in', 'a', 'row!i', 'have', 'been', 'to', 'this', 'location', 'twice', 'now', 'and', 'they', 'are', 'always', 'very', 'attentive', '-', 'always', 'checking', 'up', 'on', 'you', 'and', 'making', 'sure', 'you', 'have', 'everything', 'you', 'need', "they're", 'welcoming', 'and', 'sweet', 'and', 'always', 'more', 'than', 'happy', 'to', 'serve', 'you', 'fantastic', 'staff!', 'of', 'course', 'as', 'everyone', 'has', 'mentioned', 'the', 'wait', 'is', 'outrageous', 'but', "that's", 'expected', 'people', 'start', 'lining', 'up', 'outside', 'before', 'the', 'place', 'even', 'opens', 'so', 'definitely', 'get', 'here', 'early', 'keep', 'in', 'mind', 'they', 'are', 'not', 'able', 'to', 'seat', 'you', 'until', 'your', 'entire', 'party',
# ...

# %%
#url14
page14 = scrape_comment(url14)
print(page14)
# Out:
# ['love', 'this', 'place!', 'the', 'shrimps', 'are', 'the', 'best', 'and', 'the', 'sauce', 'is', 'out', 'of', 'this', 'world!!!', 'i', 'crave', 'for', 'this', 'stuff', 'all', 'the', 'time', 'is', 'this', 'the', 'same', 'owner', 'as', 'the', 'one', 'in', 'the', 'plantp', 'p', 'sweet', 'potato', 'fries', 'and', 'craw', 'fish', 'was', 'great', 'should', 'have', 'ordered', 'medium', 'spicyp', 'p', "i've", 'been', 'wanting', 'to', 'try', 'this', 'place', 'for', 'a', 'very', 'long', 'time', 'so', 'we', 'finally', 'committed', 'a', 'day', 'to', 'go', 'to', 'san', 'jose', 'we', 'drove', 'all', 'the', 'way', 'from', 'san', 'francisco', 'to', 'come', 'here', 'and', 'i', 'will', 'tell', 'you', 'it', 'was', 'well', 'worth', 'it', 'this', 'place', 'lived', 'up', 'to', 'all', 'of', 'my', 'expectations', 'and', 'i', 'left', 'wanting', 'more', 'although', 'my', 'stomach', 'would', 'not', 'physically', 'let', 'me', 'haha', 'we', 'got', 'the', 'gumbo', 'shrimp', 'crawfish', 'fried', 'oysters', 'corn', 
# ...

# %%
#url15
page15 = scrape_comment(url15)
print(page15)
# Out:
# ['ah', 'good', "ol'", 'boiling', 'crab', 'was', 'first', 'introduced', 'to', 'boiling', 'crab', 'a', 'few', 'years', 'ago', 'and', 'have', 'been', 'addicted', 'to', 'this', 'place', 'ever', 'since', 'the', 'wait', 'is', 'long', 'so', 'plan', 'accordingly', 'and', 'get', 'there', 'early', 'once', "you're", 'in', 'prepare', 'for', 'an', 'epic', 'meal', 'journey', 'only', 'the', 'boiling', 'crab', 'can', 'provide', 'you', 'really', "can't", 'go', 'wrong', 'with', 'whatever', 'you', 'choose', 'if', 'you', 'love', 'seafood', 'order', 'some', 'steam', 'rice', 'too', 'while', "you're", 'at', 'it', 'and', 'it', "wouldn't", 'hurt', 'to', 'accompany', 'your', 'food', 'with', 'some', 'beerp', 'p', 'go', 'for', 'the', 'shrimpwe', 'got', 'the', 'king', 'crab', 'shrimp', 'and', 'cajun', '+', 'lemon', 'pepper', 'fries', 'all', 'delicious', 'and', 'extremely', 'flavorful', 'they', 'leave', 'all', 'the', 'shell', 'on', 'the', 'seafood', 'thus', 'it', 'can', 'get', 'messy', 'when', 'you', 'eat', 'it!'
# ...

# %%
#url16
page16 = scrape_comment(url16)
print(page16)
# Out:
# ['my', 'daddy', 'loves', 'this', 'but', 'i', 'avoid', 'as', 'much', 'as', 'i', 'can', 'everytime', 'i', 'eat', 'here', 'ill', 'have', 'the', 'worse', 'food', 'poisoning', '+1', 'star', 'because', 'the', 'service', 'is', 'goodim', 'trying', 'to', 'gain', 'weight', 'not', 'lose', 'weight', 'boiling', 'crab!p', 'p', 'came', 'here', 'today', 'again', 'and', "it's", 'still', 'the', 'same', 'always', 'great', 'food', 'and', 'awesome', 'service', 'the', 'only', 'thing', 'that', 'sucks', 'here', 'obviously', 'is', 'the', 'line', 'their', 'cajun', 'fries', 'are', 'really', 'good', 'must', 'try', 'that', 'i', 'actually', 'love', 'eating', 'my', 'fries', 'after', 'putting', 'it', 'in', 'my', 'whole', 'shabang', 'sauce', 'and', 'letting', 'it', 'absorb', 'all', 'the', 'deliciousness', 'if', 'u', "haven't", 'done', 'that', 'try', 'it!', 'i', 'love', 'coming', 'here', 'when', "it's", 'not', 'crawfish', 'season', 'because', 'their', 'frozen', 'crawfish', 'is', 'still', 'good', 'frozen', 'cf', 'is',
# ...

# %%
#url17
page17 = scrape_comment(url17)
print(page17)
# Out:
# ["i'm", 'personally', 'not', 'a', 'huge', 'fan', 'of', 'cajun', 'seafood', 'type', 'restaurants', 'but', 'i', 'have', 'had', 'my', 'fair', 'share', 'of', 'eating', 'at', 'these', 'places', 'that', 'being', 'said', 'bc', 'is', 'a', 'place', 'that', 'i', 'usually', 'come', 'to', 'with', 'friends', 'if', 'we', 'had', 'to', 'choosepartially', 'out', 'of', 'convenience', 'i', "don't", 'frequent', 'this', 'location', 'much', 'but', 'it', 'is', 'the', 'closest', 'one', 'to', 'my', 'house', 'now', 'my', 'go-to', 'order', 'is', 'a', 'pound', 'of', 'shrimp', 'with', 'their', 'whole', 'shabang', 'sauce', 'and', 'an', 'order', 'of', 'their', 'cajun', 'fries', 'i', 'usually', 'will', 'share', 'with', 'another', 'person', 'since', 'it', 'is', 'a', 'good', 'amount', 'of', 'food', 'and', 'i', "can't", 'finish', 'by', 'myself', 'the', 'whole', 'shabang', 'is', 'really', 'flavorful', 'and', 'just', 'a', 'tad', 'spicy', 'even', 'when', 'you', 'order', 'it', 'mild', 'best', 'sauce', 'on', 'their', 'menu
# ...

# %%
#url18
page18 = scrape_comment(url18)
print(page18)
# Out:
# ['there', 'are', '2', 'locations', 'in', 'san', 'jose', '--', 'the', 'other', 'is', 'larger', 'has', 'shorter', 'wait', 'times', 'but', 'this', 'location', 'is', 'still', 'better', 'because', 'of', 'the', 'quality', 'of', 'the', "foodi've", 'tried', 'the', 'other', 'location', '2-3', 'times', 'and', 'the', 'sauce', 'was', 'too', 'watery', 'shrimp', "wasn't", 'very', 'fresh', 'no', 'buenothis', 'location', 'although', 'the', 'wait', 'can', 'be', 'killer', 'has', 'yet', 'to', 'fail', 'me', 'when', 'it', 'comes', 'to', 'my', 'pound', 'of', 'shrimp', 'the', 'whole', 'sha-bang', 'mediump', 'p', 'i', 'love', 'boiling', 'crab', 'i', 'would', 'give', 'this', 'place', '5', 'stars', 'but', 'the', 'only', 'reason', 'why', 'this', 'place', 'is', 'receiving', '3', 'is', 'because', 'of', 'the', 'terrible', 'customer', 'serviceour', 'server', 'was', 'the', 'girl', 'with', 'the', 'purple', 'hair', 'we', 'sat', 'for', 'almost', '10minutes', 'with', 'nothing', 'she', 'rushes', 'to', 'us', 'and', 'says
# ...

# %%
#url19
page19 = scrape_comment(url19)
print(page19)
# Out:
# ['overrated', 'we', 'should', 'have', 'saved', 'gas', 'and', 'stayed', 'local', 'honestly', 'not', 'worth', 'the', 'trip', 'you', 'would', 'think', 'if', 'all', 'the', 'sauces', 'were', 'good', 'then', 'the', 'combined', 'sauce', 'that', 'they', 'offer', 'would', 'be', 'awesome', 'so', 'not', 'the', 'case', 'overly', 'salty', 'and', 'thrown', 'together', 'you', 'can', 'tell', 'their', 'sauces', 'are', 'a', 'rush', 'job', 'no', 'love', 'whatsoever', 'first', 'and', 'last', 'time', 'herep', 'p', '**warning:', "don't", 'have', 'first', 'dates', 'here', 'unless', 'you', 'firmly', 'believe', 'that', 'this', 'person', 'genuinely', 'likes', 'you', 'and', 'has', 'a', 'fetish', 'for', 'binge-eaters', 'but', 'if', "that's", 'the', 'case', 'ditch', 'the', 'date', 'and', 'go', 'by', 'yourself***sigh*', 'i', 'love', 'the', 'boiling', 'crab', 'truth', 'is', 'if', 'i', "hadn't", 'gone', 'to', 'two', 'other', 'cajuncreole', 'places', 'i', 'would', 'have', 'probably', 'been', 'all', 'nitpicky', 'and'
# ...

# %%
#url20
page20 = scrape_comment(url20)
print(page20)
# Out:
# ['i', 'love', 'the', 'whole', 'sha-bang', '-', 'from', 'the', 'seafood', 'decor', 'to', 'the', 'seafood', 'flavor', 'this', 'place', 'is', "amazing!it's", 'great', 'for', 'family', 'and', 'friends', 'to', 'eat', 'at', 'because', 'there', 'would', 'be', 'a', 'variety', 'of', 'selections', 'to', 'choose', 'from', 'so', 'the', 'bigger', 'the', 'group', 'the', 'bigger', 'the', 'variety', 'you', 'will', 'be', 'ordering', 'my', 'crew', 'and', 'i', 'would', 'get', 'the', 'shrimp', 'clams', 'and', 'sometimes', 'the', 'nuggets', 'and', 'crawfish', 'in', 'season', "don't", 'get', 'the', 'crawfish', 'out', 'of', 'season', 'because', 'all', 'you', 'will', 'be', 'paying', 'for', 'will', 'be', 'the', 'shell', 'and', 'not', 'a', 'whole', 'lot', 'of', 'meat', 'inside', 'the', 'sauce', 'is', 'sooooo', 'goooooooood!', 'i', 'would', 'like', 'the', 'corn', 'in', 'the', 'sauce', 'bag', 'and', 'dip', 'some', 'cajun', 'fries', 'into', 'the', 'sauce!', 'i', "don't", 'understand', 'why', 'they', 'named', 'it
# ...

# %%
master_list = page1 + page2 + page3 + page4 + page5 + page6 + page7 + page8 + page9 + page10 + page11 + page12 + page13 + page14 + page15 + page16 + page17 + page18 + page19 + page20
print(master_list)
# Out:
# ['been', 'there', 'once', 'very', 'spacious', 'and', 'busy', "tooit's", 'very', 'casual', 'yellow', 'light', 'comfythe', 'waiting', 'was', '15', 'mins', 'not', 'too', 'badi', 'like', 'food', 'there', 'a', 'lotp', 'p', 'what', 'happened', 'to', 'this', 'place', 'it', 'use', 'to', 'be', 'so', 'good!i', 'live', 'like', '5', 'minutes', 'away', 'from', 'this', 'bc', 'location', 'and', 'use', 'to', 'go', 'here', 'at', 'least', 'once', 'a', 'month', 'but', 'i', "haven't", 'been', 'back', 'for', 'over', '25', 'years', 'ever', 'since', 'i', 'discovered', 'a', 'new', 'crawfish', 'place', 'on', 'berryessa', 'so', 'last', 'friday', 'we', 'were', 'lazy', 'to', 'drive', 'far', 'and', 'decided', 'to', 'give', 'them', 'another', 'try', 'we', 'ordered', '2', 'lbs', 'of', 'shrimp', '+', '2', 'lbs', 'of', 'crawfish', '+', '2', 'corns', 'shabang', 'medium', 'cajun', 'fries', 'cajun', 'wings', 'and', 'a', 'side', 'of', 'extra', 'sauce', 'crawfish', 'was', 'not', 'in', 'season', 'so', 'i', "wasn't", 'expe
# ...

# %%
stop_words = ['p', 'br', 'lang', '=', 'en', '"', ' ', '<', '/', '>', '.', '!' ,'?', ':', ';', ',','ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than']

def sanitize_3(user_input, stop_words):
    """Removes stopwords"""
    new_new_list = []
    for w in user_input:
        if w not in stop_words:
            new_new_list.append(w)
    return new_new_list

capitol_list = sanitize_3(master_list, stop_words)
capitol_list
# Out:
# ['spacious',
#  'busy',
#  "tooit's",
#  'casual',
#  'yellow',
#  'light',
#  'comfythe',
#  'waiting',
#  '15',
#  'mins',
#  'badi',
#  'like',
#  'food',
#  'lotp',
#  'happened',
#  'place',
#  'use',
#  'good!i',
#  'live',
#  'like',
#  '5',
#  'minutes',
#  'away',
#  'bc',
#  'location',
#  'use',
#  'go',
#  'least',
#  'month',
#  "haven't",
#  'back',
#  '25',
#  'years',
#  'ever',
#  'since',
#  'discovered',
#  'new',
#  'crawfish',
#  'place',
#  'berryessa',
#  'last',
#  'friday',
#  'lazy',
#  'drive',
#  'far',
#  'decided',
#  'give',
#  'another',
#  'try',
#  'ordered',
#  '2',
#  'lbs',
#  'shrimp',
#  '+',
#  '2',
#  'lbs',
#  'crawfish',
#  '+',
#  '2',
#  'corns',
#  'shabang',
#  'medium',
#  'cajun',
#  'fries',
#  'cajun',
#  'wings',
#  'side',
#  'extra',
#  'sauce',
#  'crawfish',
#  'season',
#  "wasn't",
#  'expecting',
#  'sweetness',
#  'hard',
#  'shells',
#  'shrimp',
#  'cooked',
#  'mushy',
#  'aka',
#  'dead',
#  'shrimp',
#  'disappointed',
# ...

# %%
join = ' '.join(capitol_list)

capitol_txt = open('capitol_txt.txt', 'w')
capitol_txt.write(join)
capitol_txt.close()

# %%
def list_counter(my_list):
    word_count = {}
    
    for word in my_list:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1

    list_df = pd.DataFrame(list(word_count.items()), columns = ['word', 'frequency'])
    new_list_df = list_df.sort_values(by = 'frequency', ascending = False)
    print(new_list_df)
    
list_counter(capitol_list)
# Out:
#                     word  frequency
# 107                 crab        390
# 49                shrimp        369
# 59                 sauce        318
# 213                 wait        297
# 180                 time        265
# 12                  food        260
# 242                  get        249
# 15                 place        220
# 95                  good        219
# 106              boiling        193
# 55                 fries        188
# 11                  like        185
# 314                 it's        181
# 54                 cajun        173
# 201                  one        167
# 127                whole        166
# 169               always        162
# 123              seafood        156
# 98                 order        148
# 35              crawfish        144
# 24                    go        143
# 674                would        143
# 326               really        125
# 379                 love        123
# 89                  corn        122
# ...
