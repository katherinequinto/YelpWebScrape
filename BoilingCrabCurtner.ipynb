# %% [markdown]
# # Final Project: Boiling Crab Curtner
# Kathy Quinto, Luis Arteaga, Mai Chee Vang, ENGR 120
# Last Updated: 12/12/2017
#
# Purpose: Get links, Scrape reviews from individual pages into separate lists, Combined all lists into a master list, Remove stop words from master list, Compile into .txt file

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
from re import findall
import pandas as pd

# %% [markdown]
# # Boiling Crab on Curtner Ave

# %%
url1 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?osq=The+Boiling+Crab'
url2 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=20'
url3 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=40'
url4 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=60'
url5 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=80'
url6 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=100'
url7 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=120'
url8 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=140'
url9 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=160'
url10 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=180'
url11 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=200'
url12 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=220'
url13 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=240'
url14 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=260'
url15 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=280'
url16 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=300'
url17 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=320'
url18 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=340'
url19 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=360'
url20 = 'https://www.yelp.com/biz/the-boiling-crab-san-jose-8?start=380'

# %%
def scrape_comment(link):
    """Returns parsed HTML content for COMMENT"""
    
    response = urlopen(link)
    content = response.read()
    response.close()
    
    #parse HTML file
    content_soup = soup(content, 'html.parser')

    
    #parse HTML file
    review_comment = content_soup.findAll("p", {"lang" : "en"})
    review_str = str(review_comment)
    review_lower = review_str.lower()
    new_list1 = review_lower.replace('[<p', '')
    new_list2 = new_list1.replace('br', '')
    new_list3 = new_list2.replace('lang','')
    new_list4 = new_list3.replace('[', '')
    new_list5 = new_list4.replace('<', '')
    new_list6 = new_list5.replace('=', '')
    new_list7 = new_list6.replace('"en"', '')
    new_list8 = new_list7.replace('>', '')
    new_list9 = new_list8.replace('/', '')
    new_list10 = new_list9.replace('.', '')
    new_list11 = new_list10.replace('?', '')
    new_list12 = new_list11.replace('"', '')
    new_list13 = new_list12.replace(',', '')
    new_list14 = new_list13.replace('(', '')
    new_list15 = new_list14.replace(')', '')
    review_list = new_list15.split()
    return(review_list)

# %%
#url1
page1 = scrape_comment(url1)
print(page1)
# Out:
# ["don't", 'get', 'the', 'frozen', 'crawfish', 'i', 'think', "it's", 'a', 'general', 'rule', 'of', 'thumb', 'but', 'frozen', 'crawfish', 'are', 'actually', 'tasteless', 'we', 'went', 'to', 'the', 'boiling', 'crab', 'at', 'noon', 'on', 'a', 'sunday', 'there', 'was', 'already', 'a', 'line', 'but', 'it', 'moved', 'quickly', 'and', 'we', 'were', 'seated', 'rather', 'quickly', 'they', 'offer', 'a', 'good', 'selection', 'of', 'beers', 'and', 'sodas', 'i', 'personally', 'got', 'a', 'delicious', 'raspberry', 'tea', 'we', 'ordered', 'the', 'cajun', 'fries', 'mild', '6', 'piece', 'raw', 'oyster', 'delicious', 'and', 'pounds', 'on', 'pounds', 'of', 'frozen', 'crawfish', 'no', 'fresh', 'when', 'we', 'went', 'shrimp', 'clams', 'and', 'corn', 'my', 'other', 'got', 'the', 'seafood', 'gumbo', 'with', 'rice', 'apparently', 'it', "wasn't", 'too', 'goodas', 'someone', 'who', 'can', 'barely', 'handle', 'their', 'spice', 'i', 'was', 'worried', 'with', 'just', 'getting', 'mild', 'the', 'mild', 'cajun', 'fr
# ...

# %%
#url2
page2 = scrape_comment(url2)
print(page2)
# Out:
# ["it's", 'been', '2', 'years', 'since', 'my', 'last', 'visit', 'yikes!', 'i', 'managed', 'to', 'find', 'a', 'friend', 'who', "hadn't", 'been', 'to', 'the', 'boiling', 'crab', 'yet', 'how', 'is', 'that', 'possible', 'anyway', 'we', 'thought', "we'd", 'go', 'on', 'january', '2', 'since', 'we', 'both', 'had', 'the', 'day', 'off', 'we', 'planned', 'on', 'meeting', 'at', '2:30', 'since', 'tbc', 'opens', 'at', '3', 'we', 'figured', 'it', 'would', 'be', 'empty', 'on', 'a', 'monday', 'afternoon', 'right', 'wrong!', 'there', 'was', 'a', 'long', 'line', 'that', 'reached', 'straw', 'hat', 'pizza', 'for', 'those', 'of', 'you', 'familiar', 'with', 'the', 'area', 'we', 'just', 'made', 'it', 'in', 'the', 'first', 'seating', 'there', 'was', 'literally', 'one', 'group', 'of', 'people', 'sat', 'after', 'us', 'phew!', 'my', "friend's", 'daughter', 'was', 'enthralled', 'with', 'the', 'decor', 'she', 'was', 'pointing', 'to', 'all', 'of', 'the', 'fun', 'decorations', 'including', 'the', 'shark', 'right', 
# ...

# %%
#url3
page3 = scrape_comment(url3)
print(page3)
# Out:
# ['i', 'always', 'come', 'here', 'on', 'a', 'weekday', 'anytime', 'before', '5pm', 'because', 'that', 'means', 'nolittle', 'wait', "i've", 'been', 'come', 'here', 'for', 'quite', 'awhile', 'especially', 'when', 'i', 'was', 'at', 'sjsu', 'my', 'go', 'to', 'order:', '12', 'pound', 'of', 'shrimp', 'in', 'the', 'whole', 'sha-bang', 'medium', 'a', 'corn', 'on', 'the', 'cob', 'and', 'cajun', 'fries', 'with', 'ranch', 'it', 'never', 'disappointsp', 'p', 'the', 'best', 'tasting', 'food', 'hands', 'down!', 'it', 'has', 'been', 'our', 'favorite', 'place', 'for', 'years', 'now', 'no', 'reservations', 'so', 'sign', 'up', 'n', 'go', 'shopping!!!p', 'p', 'i', 'am', 'an', 'addict', 'a', 'proud', 'addict', 'of', 'boiling', 'crabif', 'i', 'was', 'basing', 'this', 'review', 'solely', 'on', 'my', 'crazy', 'love', 'for', 'their', 'shrimp', 'drenched', 'in', 'the', 'magical', 'whole', 'shabang', 'sauce', 'then', 'totally', '5', 'stars', 'for', 'starters', "i'm", 'a', 'shrimp', 'lover', 'secondly', 'there'
# ...

# %%
#url4
page4 = scrape_comment(url4)
print(page4)
# Out:
# ['long', 'wait', 'but', 'worth', 'it', 'would', 'recommend', 'add', 'corn', '&amp;', 'potato', 'sd', 'has', 'much', 'shorter', 'linep', 'p', 'this', 'place', 'is', 'a', 'unique', 'experience', 'with', 'fair', 'prices', 'it', 'is', 'also', 'a', 'place', 'that', 'you', 'will', 'have', 'to', 'wait', 'to', 'get', 'into', 'at', 'any', 'time', 'of', 'the', 'day', 'except', 'at', 'the', 'very', 'beginning', "i've", 'been', 'the', 'table', 'that', 'just', 'missed', 'the', 'first', 'round', 'and', 'had', 'to', 'wait', 'about', '45', 'minutes', 'for', 'a', 'table', 'to', 'open', 'up', 'the', 'nice', 'thing', 'is', 'that', 'in', 'the', 'plaza', 'where', 'this', 'is', 'located', 'there', 'is', 'a', 'bunch', 'of', 'other', 'stores', 'that', 'you', 'can', 'hang', 'out', 'in', 'like', 'best', 'buy', 'i', 'do', 'really', 'enjoy', 'the', 'style', 'of', 'food', 'here', 'so', 'i', 'will', 'occasionally', 'go', 'through', 'with', 'the', 'long', 'wait', 'definitely', 'be', 'prepared', 'to', 'get', 'messy
# ...

# %%
#url5
page5 = scrape_comment(url5)
print(page5)
# Out:
# ['i', 'got', 'a', 'order', 'of', 'the', 'xxx', 'cajun', 'shrimp', 'i', 'assumed', 'that', 'i', 'was', 'going', 'to', 'hella', 'spicy', 'but', 'i', 'was', 'not', 'much', 'kick', 'for', 'me', 'i', 'wish', 'it', 'was', 'as', 'spicy', 'as', 'it', 'said', 'it', 'would', 'be', 'but', 'it', 'was', 'still', 'delicious', 'the', 'cajun', 'fries', 'dipped', 'in', 'the', 'sauce', 'was', 'also', 'delicious', 'but', 'i', 'would', 'say', 'the', 'downside', 'of', 'this', 'place', 'if', 'the', 'wait', 'it', 'was', 'about', '1', '12', 'he', 'wait', 'on', 'a', 'sunday', 'so', 'i', 'will', 'definitely', 'say', 'come', 'when', 'it', 'opensp', 'p', 'i', 'love', 'the', 'seafood', 'here', 'so', 'much。today', 'is', 'my', 'birthday，my', 'husband', 'ordered', 'a', 'lot', 'of', 'things', 'here。we', 'had', '3', 'lb', 'shirmps，king', 'crab', 'legs，corns，wings', 'and', 'oysters，the', 'shirmp', 'was', 'not', 'fresh', 'and', 'very', 'soft，taste', 'bad！others', 'foods', 'were', 'good！p', 'p', 'okay', 'i', 'have', 'be
# ...

# %%
#url6
page6 = scrape_comment(url6)
print(page6)
# Out:
# ['my', 'boyfriend', 'took', 'me', 'here', 'for', 'my', 'birthday', 'i', 'had', 'never', 'heard', 'of', 'it', 'but', 'i', 'absolutely', 'loved', 'it!', 'the', 'food', 'was', 'delicious', 'but', 'the', 'experience', 'was', 'really', 'fun', 'also', 'at', 'first', 'i', 'was', 'apprehensive', 'about', 'tearing', 'off', 'shrimp', 'heads', 'and', 'legs', 'but', 'it', 'was', 'really', 'not', 'a', 'big', 'deal', 'warning:', 'the', 'spicy', 'really', 'is', 'spicy', 'so', "don't", 'underestimate', 'their', 'menu', 'choices', 'for', 'heat', 'we', 'also', 'had', 'the', 'french', 'fries', 'which', 'were', 'delicious', 'for', 'dipping', 'into', 'the', 'shrimp', 'sauces', 'in', 'between', 'beheadingsp', 'p', 'extremely', 'long', 'wait', 'times', 'we', 'waited', 'over', '1:45', 'to', 'be', 'seated', 'however', 'as', 'soon', 'as', 'we', 'were', 'seated', 'we', 'ordered', 'and', 'food', 'came', 'after', '20', 'minutes', 'food', 'was', 'delicious', 'the', 'guys', 'that', 'helped', 'us', 'was', 'nice', '
# ...

# %%
#url7
page7 = scrape_comment(url7)
print(page7)
# Out:
# ['every', 'time', 'i', 'go', 'to', 'boiling', 'crab', 'i', 'swear', 'my', 'happiness', 'level', 'raises', 'to', '100', 'i', 'was', 'able', 'to', 'visit', 'both', 'locations', 'in', 'san', 'jose', 'during', 'my', 'most', 'recent', 'visit', 'and', 'have', 'to', 'say', 'this', 'one', 'is', 'just', 'a', 'little', 'bit', 'better', 'since', 'the', 'location', 'is', 'bigger', 'i', 'always', 'order', 'crawfish', 'and', 'shrimp', 'medium', 'spicy', 'and', 'the', 'flavor', 'is', 'always', 'perfection', 'the', 'service', 'is', 'consistently', 'good', 'and', 'they', 'make', 'sure', 'you', 'get', 'everything', 'you', 'need', 'i', 'definitely', 'recommend', 'going', 'for', 'lunch', 'dinner', 'the', 'wait', "isn't", 'as', 'bad', 'they', 'always', 'recommended', 'coming', 'back', 'a', 'little', 'bit', 'before', 'your', 'suggested', 'time', 'which', 'is', 'great', 'expect', 'at', 'least', 'an', 'hour', 'to', 'two', 'hours', 'of', 'a', 'wait', 'but', "don't", 'get', 'frustrated', 'i', 'swear', "it's",
# ...

# %%
#url8
page8 = scrape_comment(url8)
print(page8)
# Out:
# ['i', 'go', 'to', 'this', 'location', 'all', 'the', 'time', 'long', 'wait', 'every', 'single', 'time', 'but', 'food', 'and', 'service', 'is', 'worth', 'it', 'to', 'me', 'went', 'there', 'over', 'the', 'weekend', 'my', 'wait', 'was', 'only', 'an', "houri've", 'waited', 'longer', 'is', 'the', 'past', 'and', 'the', 'food', 'came', 'out', 'very', 'fast', 'the', 'server', 'always', 'checked', 'on', 'us', 'and', 'never', 'forgot', 'about', 'us', 'i', 'forgot', 'his', 'name', 'i', 'want', 'to', 'say', "it's", 'young', 'but', 'could', 'be', 'wrong', 'i', 'will', 'definitely', 'return', 'forsure', 'p', 'p', 'the', 'boiling', 'crab', 'is', 'the', 'go-to', 'cajun', 'and', 'seafood', 'fix', 'in', 'the', '408!consistent', 'all', 'the', 'time', "it's", 'a', 'shame', 'that', 'this', 'place', 'is', 'so', 'popular', 'there', 'have', 'times', 'i', 'have', 'waited', 'over', 'two', 'hours', 'and', 'was', 'not', 'guaranteed', 'seating', 'but', 'if', 'all', 'fails', 'i', 'can', 'order', 'the', 'food', 'to
# ...

# %%
#url9
page9 = scrape_comment(url9)
print(page9)
# Out:
# ['i', 'visited', 'at', 'this', 'restaurant', 'pm9:45', 'on', 'wednesday', 'june', '24', 'it', 'was', 'almost', 'time', 'to', 'close', 'but', 'there', 'were', 'some', 'guests', 'waiting', 'for', 'luckily', 'i', 'could', 'get', 'the', 'table', 'soon', 'the', 'restaurant', 'was', 'full', 'of', 'guestsi', 'ordered', '1pound', 'shrimp', 'with', 'lemon', 'pepper', 'and', 'fried', 'shrimp', 'basket', 'it', 'was', 'appropriate', 'portion', 'for', 'me', 'shrimps', 'were', 'very', 'good', 'for', 'drinking', 'shack', 'top', 'the', 'fried', 'basket', 'was', 'good', 'combination', 'with', "shrimpsi'd", 'like', 'to', 'come', 'againp', 'p', 'omfg', 'wait', 'time', 'was', '2', 'and', 'a', 'half', 'hours', 'on', 'friday', 'night!!!', 'my', 'cousins', 'and', 'i', 'almost', "didn't", 'get', 'seated', 'after', 'the', 'two', 'hour', 'wait', 'they', 'said', 'they', "didn't", 'have', 'any', 'tables', 'so', 'we', 'stood', 'in', 'line', 'to', 'order', 'it', 'to', 'go', 'waiter', 'came', 'back', 'and', 'said'
# ...

# %%
#url10
page10 = scrape_comment(url10)
print(page10)
# Out:
# ['another', 'review', 'where', 'i', 'want', 'to', 'cry', 'while', 'typing', 'it', 'up', 'because', "it's", 'so', 'good', 'and', 'i', 'want', 'some', 'this', 'minute', 'but', "can't!boiling", 'crab', 'is', 'one', 'of', 'my', 'favorite', 'places', 'to', 'eat', 'atmy', 'ex', 'introduced', 'this', 'place', 'to', 'me', 'lol', 'guess', 'he', 'was', 'good', 'for', 'something', 'this', 'one', 'on', 'curtner', 'is', 'so', 'much', 'more', 'spacious', 'and', 'naturally', "it's", 'cleaner', 'than', 'the', 'one', 'on', 'capitol', 'since', "it's", 'newer', 'if', 'this', 'is', 'your', 'first', 'time', 'beware', 'of', 'the', 'long', 'wait!', 'one', 'time', 'my', 'husband', 'and', 'i', 'waited', '3', 'hours', 'we', 'came', 'on', 'a', 'friday', 'night', 'and', 'the', 'place', 'was', 'packed!', 'usually', "you're", 'looking', 'at', 'a', '2', 'hour', 'wait', 'there', 'are', 'places', 'in', 'walking', 'distance', 'to', 'kill', 'time', 'so', "it's", 'not', 'that', 'bad', 'and', 'it', 'is', 'definitely', '
# ...

# %%
#url11
page11 = scrape_comment(url11)
print(page11)
# Out:
# ['we', 'got', 'there', '30', 'minutes', 'after', 'they', 'opened', 'and', 'it', 'got', 'busy', 'pretty', 'fast', 'luckily', 'we', 'only', 'had', '3', 'people', 'and', 'they', 'got', 'us', 'a', 'seat', 'as', 'soon', 'as', 'we', 'walked', 'in', 'service', 'was', 'pretty', 'good', "they're", 'really', 'friendly', 'the', 'wait', 'time', 'for', 'our', 'food', "wasn't", 'too', 'long', 'either', 'i', 'got', 'a', 'pound', 'of', 'crawfish', 'and', 'it', 'was', 'very', 'tasty', 'the', 'cajun', 'fries', 'are', 'really', 'addicting', 'too', 'the', 'bill', 'was', 'not', 'bad', 'at', 'all', 'for', 'what', 'i', 'usually', 'pay', 'for', 'seafood', 'places', 'like', 'thisp', 'p', 'i', 'love', 'this', 'place', 'i', 'found', 'out', 'about', 'the', 'boiling', 'crab', 'when', 'having', 'a', 'consultation', 'for', 'smart', 'liposuction', 'no', 'bullshit!!', 'i', 'was', 'new', 'to', 'cali', 'and', 'wanted', 'to', 'drop', 'some', 'poundsafter', 'eating', 'here', 'i', 'learned', 'that', 'i', "don't", 'give',
# ...

# %%
#url12
page12 = scrape_comment(url12)
print(page12)
# Out:
# ['im', 'a', 'generous', 'yelper', 'bit', 'all', 'generosity', 'aside', 'this', 'place', 'has', 'good', 'food', 'good', 'service', 'decent', 'price', 'the', 'beers', 'were', 'a', 'little', 'bit', 'pricey', 'but', 'other', 'then', 'that', 'great', 'environment', 'alive', '!!', 'ill', 'be', 'backkkp', 'p', 'everything', 'from', 'food', 'quality', 'freshness', 'tastes', 'and', 'service', 'were', 'bad', 'the', 'clam', 'i', 'had', 'tonight', 'actually', 'stinks', 'when', 'i', 'opened', 'the', 'bag', 'definiately', "wasn't", 'fresh', 'the', 'waiter', 'never', 'refill', 'our', 'water', 'i', 'also', 'had', 'the', 'king', 'crab', 'legs', 'and', 'waiter', 'never', 'bough', 'me', 'anything', 'to', 'crack', 'them', 'opened', 'i', 'had', 'to', 'ask', 'him', 'for', 'it', 'twice', 'before', 'i', 'had', 'gotten', 'itthere', 'are', 'so', 'many', 'other', 'good', 'asian', 'crawfishseafood', 'places', 'that', 'are', 'way', 'better', 'than', 'this', 'place', 'crawshack', 'kicking', 'crab', 'and', 'etcp',
# ...

# %%
#url13
page13 = scrape_comment(url13)
print(page13)
# Out:
# ['been', 'meaning', 'to', 'post', 'a', 'review', 'for', 'a', 'while', 'but', "didn't", 'get', 'the', 'chance', 'until', 'now', 'boiling', 'crab', 'was', 'always', 'my', 'go-to', 'crawfish', 'place', 'it', 'has', 'its', 'upsides', 'and', 'downsides', 'the', 'prices', 'are', 'cheap', 'and', 'reasonable', 'but', 'recently', "i've", 'been', 'really', 'unimpressed', 'with', 'the', 'place', 'cause', 'the', 'quality', 'has', 'just', 'been', 'suckingfirst', 'of', 'all', 'boiling', 'crab', 'always', 'i', 'mean', 'always', 'has', 'the', 'worse', 'waits', 'on', 'a', 'packed', 'day', 'it', 'ranges', 'up', 'to', '2', 'hours', 'for', 'a', 'table', 'i', 'mean', 'seriously', 'and', 'the', 'quality', 'of', 'the', 'seafood', 'has', 'really', 'dropped', 'the', 'size', 'of', 'the', 'crawfish', '&amp;', 'shrimp', 'are', 'just', 'so', 'small', 'the', 'sauce', 'has', 'been', 'oily', 'and', 'i', 'feel', 'like', 'they', 'never', 'really', 'give', 'us', 'enough', 'also', 'lemme', 'tell', 'you', 'i', 'had', 't
# ...

# %%
#url14
page14 = scrape_comment(url14)
print(page14)
# Out:
# ['i', 'gave', 'it', 'a', '1', 'star', 'not', 'because', 'of', 'the', 'food', 'the', 'shrimp', 'is', 'always', 'good', 'but', 'when', 'you', 'call', "it'll", 'ring', 'and', 'ring', 'and', 'they', "don't", 'ever', 'answer', 'both', 'the', 'capitol', 'one', 'and', 'curtner', 'one', 'will', 'either', 'put', 'their', 'phones', 'straight', 'to', 'voicemail', 'which', 'they', 'never', 'check', 'or', 'will', 'let', 'their', 'phones', 'stay', 'off', 'the', 'hook', 'so', 'you', "can't", 'even', 'get', 'through', 'to', 'place', 'an', 'order', 'to', 'gop', 'p', 'the', 'sauce', 'got', 'way', 'saltier', 'or', 'maybe', 'now', 'that', 'i', 'am', 'older', 'it', 'just', 'seems', 'like', 'it', 'also', 'the', 'oysters', 'used', 'to', 'taste', 'good', 'but', 'now', "they're", 'pretty', 'gross', 'maybe', 'being', 'older', 'i', 'ate', 'like', 'real', 'oysters', 'too', 'hahathey', 'changed', 'their', 'limes', 'to', 'lemons', 'and', 'they', "don't", 'cut', 'it', 'in', 'wedges', 'anymore', 'the', 'lemons', 'a
# ...

# %%
#url15
page15 = scrape_comment(url15)
print(page15)
# Out:
# ['terrible', 'customer', 'service', 'i', 'just', 'needed', 'to', 'know', 'my', 'wait', 'time', 'while', 'shopping', 'and', 'the', 'cashier', 'and', 'manager', "didn't", 'want', 'to', 'check', 'the', 'time', 'for', 'me', 'i', 'would', 'recommend', 'you', 'change', 'your', 'policy', 'and', 'learn', 'more', 'about', 'customer', 'servicep', 'p', 'can', 'be', 'a', 'really', 'long', 'wait!!', 'but', 'good', 'deal', 'on', 'seafood', 'really', 'casual', 'and', 'the', 'corn', 'is', 'a', 'good', 'add', 'on', 'good', 'to', 'take', 'a', 'group', 'and', 'eat', 'family', 'style', 'not', 'good', 'for', 'vegetarians', 'or', 'first', 'datesp', 'p', 'i', 'think', 'this', 'place', 'is', 'the', 'best', 'seafood', 'restaurant', 'in', 'the', 'bay', 'area', 'so', 'far', 'but', 'there', 'might', 'be', 'others', 'out', 'there', 'little', 'better', 'but', 'the', 'problem', 'about', 'this', 'place', 'is', 'that', 'u', 'must', 'have', 'the', 'time', 'to', 'wait', 'for', 'seating', 'takes', 'about', '1', '-', '2
# ...

# %%
#url16
page16 = scrape_comment(url16)
print(page16)
# Out:
# ['i', 'was', 'wondering', 'why', 'this', 'location', 'had', 'a', 'half', 'star', 'lower', 'rating', 'than', 'the', 'other', 'one', 'since', 'i', 'remember', 'eating', 'here', 'a', 'couple', 'years', 'ago', 'and', 'really', 'enjoying', 'it', 'after', 'trying', 'it', 'again', 'last', 'night', 'i', 'now', 'know', 'why', 'it', "wasn't", 'an', 'unsatisfying', 'experience', 'but', 'if', "we're", 'comparing', 'it', 'to', 'the', 'other', 'location', 'it', 'can', 'be', 'a', 'little', 'disappointing', 'the', 'wait', 'is', 'long', 'regardless', 'of', 'which', 'location', 'you', 'choose', 'to', 'go', 'to', 'wait', 'around', 'it', 'usually', 'always', 'goes', 'by', 'quicker', 'than', 'what', 'they', 'estimate', 'however', 'when', 'it', 'came', 'to', 'the', 'flavors', ':', 'i', "can't", 'quite', 'put', 'my', 'finger', 'on', 'it', 'but', 'something', 'was', 'definitely', 'lacking', 'flavor', 'wise', 'also', 'most', 'of', 'my', 'shrimp', 'was', 'mushy', 'oysters', 'were', 'good', 'but', 'kind', 'of'
# ...

# %%
#url17
page17 = scrape_comment(url17)
print(page17)
# Out:
# ['update:', 'after', 'my', 'unpleasant', 'experience', 'about', 'a', 'month', 'ago', 'i', 'went', 'back', 'to', 'boiling', 'crab', 'and', 'i', 'had', 'a', 'much', 'better', 'experience', 'they', 'apologized', 'for', 'the', 'previous', 'experience', 'that', 'i', 'hadwe', 'were', 'consistently', 'checked', 'up', 'on', 'by', 'our', 'waitresses', 'and', 'made', 'sure', 'we', 'had', 'everything', 'we', 'needed', 'amber', 'the', 'manager', 'also', 'addressed', 'my', 'issue', 'professionally', "i'm", 'happy', 'with', "today's", 'experiencep', 'p', 'dissatisfied', 'with', 'the', 'service', 'employees', 'letting', 'their', 'friends', 'ahead', 'of', 'people', 'that', 'were', 'waiting', 'over', 'an', 'hour', 'including', 'us', 'terrible', 'the', 'food', 'on', 'the', 'other', 'hand', 'is', 'amazing', 'and', 'we', 'took', 'the', 'sauces', 'home', 'i', 'would', 'definitely', 'try', 'a', 'different', 'locationp', 'p', 'i', 'live', 'in', 'utah', 'now', 'but', 'i', 'have', 'to', 'get', 'my', 'boiling
# ...

# %%
#url18
page18 = scrape_comment(url18)
print(page18)
# Out:
# ['if', "you're", 'planning', 'on', 'coming', 'here', "don't", 'come', 'hungry', 'the', 'wait', 'time', 'will', 'only', 'piss', 'you', 'off', 'to', 'hangry', 'status', 'the', 'food', 'was', 'decent', 'the', 'service', 'could', 'have', 'been', 'better', 'thankfully', 'amber', 'managed', 'to', 'provide', 'some', 'resolution', 'to', 'the', 'situation', 'in', 'any', 'case', 'we', 'were', 'able', 'to', 'get', 'out', 'fix', 'of', 'eating', 'boiled', 'seasoned', 'seafood', 'out', 'of', 'a', 'plastic', 'bagp', 'p', 'definitely', 'the', 'best', 'crab', 'legs', 'i', 'have', 'eaten', 'the', 'wait', 'here', 'is', 'huge', '&amp;', 'they', "don't", 'reservations', 'so', 'come', 'during', 'off-peak', 'times', 'or', 'be', 'prepared', 'to', 'wait', 'especially', 'for', 'large', 'groups', 'we', 'got', 'seated', 'in', '20', 'mins', 'or', 'so', 'the', 'crabs', 'were', 'delicious', '&amp;', 'amazing', 'the', 'prawns', 'were', 'decent', 'as', 'well', 'i', 'will', 'definitely', 'go', 'for', 'crab-only', 'or
# ...

# %%
#url19
page19 = scrape_comment(url19)
print(page19)
# Out:
# ['i', 'love', 'fresh', 'seafood', 'and', 'we', 'live', 'nearby', 'and', 'thought', 'we', 'would', 'try', 'this', 'place', 'the', 'line', 'is', 'always', 'crazy', 'we', 'waited', 'for', 'an', 'hour', 'for', 'a', 'table', 'of', '3', 'the', 'place', 'is', 'very', 'casualseems', 'like', 'no', 'one', 'is', 'in', 'uniform', 'so', 'its', 'hard', 'to', 'tell', 'who', 'is', 'working', 'we', 'tried', 'their', 'special', 'sauce', 'for', 'our', 'bucket', 'and', 'it', 'was', 'way', 'oversauceddrowning', 'really', 'really', 'was', 'expecting', 'something', 'better', 'for', 'the', 'hype', 'we', 'wont', 'go', 'back', 'but', 'the', 'seafood', 'was', 'fine', 'a', 'litrle', 'pricy', 'but', 'its', 'expectedp', 'p', '2nd', 'time', 'coming', 'back', 'to', 'this', 'location', 'at', 'the', 'plant', 'my', 'server', 'linh', 'gave', 'the', 'best', 'service', "i've", 'had', 'in', 'awhile!', 'i', 'also', 'work', 'at', 'a', 'restaurant', 'myself', 'and', 'i', 'know', 'how', 'it', 'is', 'on', 'the', 'other', 'side
# ...

# %%
#url20
page20 = scrape_comment(url20)
print(page20)
# Out:
# ['this', 'is', 'the', 'one', 'place', 'i', 'never', 'ever', 'get', 'tired', 'of!', 'i', 'always', 'get', 'the', 'pound', 'of', 'shrimp', 'with', 'the', 'whole', 'shebang', 'sauce', 'spicy!', 'just', 'thinking', 'about', 'it', 'makes', 'my', 'mouth', 'water!', 'at', 'first', 'i', 'thought', 'it', 'was', 'weird', 'that', 'food', 'would', 'be', 'delivered', 'in', 'a', 'plastic', 'bag', 'and', 'that', 'you', 'would', 'have', 'to', 'eat', 'with', 'your', 'hands', 'but', 'then', 'i', 'tried', 'their', 'food', 'and', 'i', 'was', 'in', 'heaven', 'seriously', 'this', 'is', 'my', 'happy', 'place', 'however', 'the', 'wait', 'can', 'be', 'horrendous!!', 'and', 'this', 'is', 'anytime', 'after', '6ish', 'weekends', 'and', 'weekdays', 'weekends', 'just', 'avoid', 'this', 'place', 'unless', 'you', 'come', 'super', 'early', "i've", 'been', 'here', 'on', 'a', 'sunday', 'night', 'and', 'waited', '2', 'hours', 'and', "i've", 'been', 'here', 'on', 'a', 'monday', 'evening', 'around', '4:00', 'and', 'was',
# ...

# %%
master_list = page1 + page2 + page3 + page4 + page5 + page6 + page7 + page8 + page9 + page10 + page11 + page12 + page13 + page14 + page15 + page16 + page17 + page18 + page19 + page20
print(master_list)
# Out:
# ["don't", 'get', 'the', 'frozen', 'crawfish', 'i', 'think', "it's", 'a', 'general', 'rule', 'of', 'thumb', 'but', 'frozen', 'crawfish', 'are', 'actually', 'tasteless', 'we', 'went', 'to', 'the', 'boiling', 'crab', 'at', 'noon', 'on', 'a', 'sunday', 'there', 'was', 'already', 'a', 'line', 'but', 'it', 'moved', 'quickly', 'and', 'we', 'were', 'seated', 'rather', 'quickly', 'they', 'offer', 'a', 'good', 'selection', 'of', 'beers', 'and', 'sodas', 'i', 'personally', 'got', 'a', 'delicious', 'raspberry', 'tea', 'we', 'ordered', 'the', 'cajun', 'fries', 'mild', '6', 'piece', 'raw', 'oyster', 'delicious', 'and', 'pounds', 'on', 'pounds', 'of', 'frozen', 'crawfish', 'no', 'fresh', 'when', 'we', 'went', 'shrimp', 'clams', 'and', 'corn', 'my', 'other', 'got', 'the', 'seafood', 'gumbo', 'with', 'rice', 'apparently', 'it', "wasn't", 'too', 'goodas', 'someone', 'who', 'can', 'barely', 'handle', 'their', 'spice', 'i', 'was', 'worried', 'with', 'just', 'getting', 'mild', 'the', 'mild', 'cajun', 'fr
# ...

# %%
stop_words = ['p', 'br', 'lang', '=', 'en', '"', ' ', '<', '/', '>', '.', '!' ,'?', ':', ';', ',', 'get', 'go', 'don\'t', 'one', 'really', 'also', 'come', 'it\'s','ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than']

def sanitize_3(user_input, stop_words):
    """Removes stopwords"""
    new_new_list = []
    for w in user_input:
        if w not in stop_words:
            new_new_list.append(w)
    return new_new_list

curtner_list = sanitize_3(master_list, stop_words)
curtner_list
# Out:
# ['frozen',
#  'crawfish',
#  'think',
#  'general',
#  'rule',
#  'thumb',
#  'frozen',
#  'crawfish',
#  'actually',
#  'tasteless',
#  'went',
#  'boiling',
#  'crab',
#  'noon',
#  'sunday',
#  'already',
#  'line',
#  'moved',
#  'quickly',
#  'seated',
#  'rather',
#  'quickly',
#  'offer',
#  'good',
#  'selection',
#  'beers',
#  'sodas',
#  'personally',
#  'got',
#  'delicious',
#  'raspberry',
#  'tea',
#  'ordered',
#  'cajun',
#  'fries',
#  'mild',
#  '6',
#  'piece',
#  'raw',
#  'oyster',
#  'delicious',
#  'pounds',
#  'pounds',
#  'frozen',
#  'crawfish',
#  'fresh',
#  'went',
#  'shrimp',
#  'clams',
#  'corn',
#  'got',
#  'seafood',
#  'gumbo',
#  'rice',
#  'apparently',
#  "wasn't",
#  'goodas',
#  'someone',
#  'barely',
#  'handle',
#  'spice',
#  'worried',
#  'getting',
#  'mild',
#  'mild',
#  'cajun',
#  'fries',
#  'pretty',
#  'spicy',
#  'already',
#  "i'd",
#  'definitely',
#  'advise',
#  "can't",
#  'handle',
#  'heat',
#  'non-spicy',
#  'even',
# ...

# %%
join = ' '.join(curtner_list)

curtner_txt = open('curtner_txt.txt', 'w')
curtner_txt.write(join)
curtner_txt.close()

# %%
def list_counter(my_list):
    word_count = {}
    
    for word in my_list:
        if word in word_count:
            word_count[word] += 1
        else:
            word_count[word] = 1

    list_df = pd.DataFrame(list(word_count.items()), columns = ['word', 'frequency'])
    new_list_df = list_df.sort_values(by = 'frequency', ascending = False)
    print(new_list_df)
list_counter(curtner_list)
# Out:
#              word  frequency
# 165          wait        407
# 10           crab        390
# 39         shrimp        360
# 152          time        297
# 95          sauce        293
# 151          food        280
# 20           good        260
# 571         place        240
# 9         boiling        227
# 106          like        211
# 31          fries        202
# 93          whole        197
# 210        always        192
# 30          cajun        184
# 146         order        162
# 162       service        140
# 42        seafood        133
# 401          long        127
# 730          love        120
# 25            got        115
# 29        ordered        115
# 80          would        115
# 398         great        113
# 283         pound        112
# 55          spicy        108
# 74           came        107
# 255          i've        106
# 288            us        104
# 439             2        102
# 54         pretty         99
# ...           ...        ...
# ...

# %% [markdown]
# # We tried to create a word cloud using python, but we ran into issues we could not solve.

# %%
from os import path
from wordcloud import WordCloud

d = path.dirname(__file__)

# Read the whole text.
text = open(path.join(d, 'curtner_txt.txt')).read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-60-1b493a5d6d55> in <module>()
#       1 from os import path
# ----> 2 from wordcloud import WordCloud
#       3
#       4 d = path.dirname(__file__)
#       5
#
# ModuleNotFoundError: No module named 'wordcloud'
